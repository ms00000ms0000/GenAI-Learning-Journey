# %% [markdown]
# #### Creating Vector Embeddings

# %%
from sentence_transformers import SentenceTransformer
model=SentenceTransformer("all-MiniLM-L6-v2")
embedding=model.encode("I love Machine Learning")
print(len(embedding))
print(embedding[:10])
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# 384
# [-0.04363634 -0.05905434  0.08201234 -0.01076718  0.06119589 -0.05515972
#  -0.00290437 -0.03672323  0.02139716 -0.00756045]

# %% [markdown]
# ####  Cosine Similarity Calculation

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
model=SentenceTransformer("all-MiniLM-L6-v2")
text1=model.encode("Dog")
text2=model.encode("Puppy")
score=cosine_similarity([text1], [text2])
print(score)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# [[0.8040067]]
